# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key
import requests
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
#determine how to properly format current description 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url).json()
print(city_weather)
description=city_weather["weather"][0]["description"]
description
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 95.77, 'feels_like': 93.74, 'temp_min': 95.77, 'temp_max': 95.77, 'pressure': 1013, 'humidity': 25, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.92, 'deg': 234, 'gust': 9.66}, 'clouds': {'all': 66}, 'dt': 1658604595, 'sys': {'country': 'US', 'sunrise': 1658568464, 'sunset': 1658621602}, 'timezone': -14400, 'id': 4930956, 'name': 'Boston', 'cod': 200}
# 'broken clouds'

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | nouadhibou
# Processing Record 3 of Set 1 | bubaque
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | le port
# Processing Record 6 of Set 1 | sechura
# Processing Record 7 of Set 1 | aketi
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | vestmanna
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | maceio
# Processing Record 20 of Set 1 | yar-sale
# Processing Record 21 of Set 1 | dodge city
# Processing Record 22 of Set 1 | evans
# Processing Record 23 of Set 1 | coruripe
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | kadnikov
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | bethanien
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | ambon
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | constitucion
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | sabang
# Processing Record 38 of Set 1 | katobu
# Processing Record 39 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 40 of Set 1 | jadu
# Processing Record 41 of Set 1 | san rafael
# Processing Record 42 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 1 | hays
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | vila velha
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | mokrous
# Processing Record 4 of Set 2 | wasilla
# Processing Record 5 of Set 2 | chapais
# Processing Record 6 of Set 2 | komsomolskiy
# Processing Record 7 of Set 2 | puerto baquerizo moreno
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | paita
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | atocha
# Processing Record 12 of Set 2 | evensk
# Processing Record 13 of Set 2 | kahului
# Processing Record 14 of Set 2 | tiarei
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | shu
# Processing Record 17 of Set 2 | flinders
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | port blair
# Processing Record 25 of Set 2 | opuwo
# Processing Record 26 of Set 2 | nelson bay
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | tatarskaya pishlya
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | nalut
# Processing Record 31 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 2 | caluquembe
# Processing Record 33 of Set 2 | nhulunbuy
# Processing Record 34 of Set 2 | hami
# Processing Record 35 of Set 2 | ojinaga
# Processing Record 36 of Set 2 | kalabo
# Processing Record 37 of Set 2 | kalashnikovo
# Processing Record 38 of Set 2 | freiberg
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | lazaro cardenas
# Processing Record 41 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | rapar
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | ternate
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | la roxas
# Processing Record 50 of Set 2 | itarema
# Processing Record 1 of Set 3 | adet
# Processing Record 2 of Set 3 | batticaloa
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | gimli
# Processing Record 6 of Set 3 | pandrup
# Processing Record 7 of Set 3 | mangan
# Processing Record 8 of Set 3 | tilichiki
# Processing Record 9 of Set 3 | skovde
# City not found. Skipping...
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | viedma
# Processing Record 12 of Set 3 | hutchinson
# Processing Record 13 of Set 3 | nisia floresta
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | mehamn
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | guerrero negro
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | badarpur
# Processing Record 20 of Set 3 | mkushi
# Processing Record 21 of Set 3 | ajdabiya
# Processing Record 22 of Set 3 | adrar
# Processing Record 23 of Set 3 | zarubino
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | tefe
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | disna
# Processing Record 29 of Set 3 | jabinyanah
# Processing Record 30 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 3 | nandigama
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | joshimath
# Processing Record 36 of Set 3 | kalanchak
# Processing Record 37 of Set 3 | tortoli
# Processing Record 38 of Set 3 | rapid valley
# Processing Record 39 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 3 | baherden
# Processing Record 41 of Set 3 | bagdarin
# Processing Record 42 of Set 3 | iquique
# Processing Record 43 of Set 3 | akyab
# Processing Record 44 of Set 3 | gamba
# Processing Record 45 of Set 3 | marawi
# Processing Record 46 of Set 3 | huancabamba
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | puerto escondido
# Processing Record 49 of Set 3 | te anau
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | manbij
# Processing Record 2 of Set 4 | lagoa
# Processing Record 3 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | dzilam gonzalez
# Processing Record 6 of Set 4 | kupang
# Processing Record 7 of Set 4 | araguacu
# Processing Record 8 of Set 4 | xining
# Processing Record 9 of Set 4 | shimoda
# Processing Record 10 of Set 4 | el faiyum
# City not found. Skipping...
# Processing Record 11 of Set 4 | road town
# Processing Record 12 of Set 4 | anchorage
# Processing Record 13 of Set 4 | parana
# Processing Record 14 of Set 4 | mangrol
# Processing Record 15 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 4 | arman
# Processing Record 17 of Set 4 | banda aceh
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | ciudad bolivar
# Processing Record 20 of Set 4 | canico
# Processing Record 21 of Set 4 | bluff
# Processing Record 22 of Set 4 | broome
# Processing Record 23 of Set 4 | honiara
# Processing Record 24 of Set 4 | tura
# Processing Record 25 of Set 4 | bathsheba
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | zabol
# Processing Record 29 of Set 4 | avarua
# Processing Record 30 of Set 4 | alice springs
# Processing Record 31 of Set 4 | alihe
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | camacha
# Processing Record 35 of Set 4 | victor harbor
# Processing Record 36 of Set 4 | elverum
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 4 | changli
# Processing Record 40 of Set 4 | belaya gora
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | rocha
# Processing Record 43 of Set 4 | stornoway
# Processing Record 44 of Set 4 | sorong
# Processing Record 45 of Set 4 | hokitika
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | husavik
# Processing Record 48 of Set 4 | rosarito
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | portland
# Processing Record 1 of Set 5 | turukhansk
# Processing Record 2 of Set 5 | luganville
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | chimbote
# Processing Record 5 of Set 5 | nikolskoye
# Processing Record 6 of Set 5 | znamenka
# Processing Record 7 of Set 5 | merrill
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | soyo
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | capreol
# Processing Record 13 of Set 5 | yeppoon
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | boshnyakovo
# Processing Record 16 of Set 5 | la sarre
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | marsh harbour
# Processing Record 19 of Set 5 | qinzhou
# Processing Record 20 of Set 5 | donskoye
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | taltal
# Processing Record 24 of Set 5 | tahe
# Processing Record 25 of Set 5 | bonfim
# Processing Record 26 of Set 5 | jumla
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | peterhead
# Processing Record 29 of Set 5 | coquimbo
# Processing Record 30 of Set 5 | point pleasant
# Processing Record 31 of Set 5 | goderich
# Processing Record 32 of Set 5 | ise
# Processing Record 33 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | bam
# Processing Record 36 of Set 5 | havre-saint-pierre
# Processing Record 37 of Set 5 | chippewa falls
# Processing Record 38 of Set 5 | suntar
# Processing Record 39 of Set 5 | port lincoln
# Processing Record 40 of Set 5 | abu dhabi
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | trinidad
# Processing Record 43 of Set 5 | herat
# Processing Record 44 of Set 5 | fairbanks
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | lyuban
# Processing Record 48 of Set 5 | tabas
# Processing Record 49 of Set 5 | elban
# Processing Record 50 of Set 5 | voyvozh
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | strezhevoy
# Processing Record 3 of Set 6 | barcelos
# Processing Record 4 of Set 6 | kenai
# Processing Record 5 of Set 6 | yekaterinovka
# Processing Record 6 of Set 6 | galesong
# Processing Record 7 of Set 6 | camacari
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | ravar
# Processing Record 10 of Set 6 | sinnamary
# Processing Record 11 of Set 6 | mata
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | karlstad
# Processing Record 14 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | rio grande
# Processing Record 17 of Set 6 | kavaratti
# Processing Record 18 of Set 6 | kutum
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 6 | visnes
# Processing Record 23 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 6 | havelock
# Processing Record 25 of Set 6 | sept-iles
# Processing Record 26 of Set 6 | morristown
# Processing Record 27 of Set 6 | kysyl-syr
# Processing Record 28 of Set 6 | lata
# Processing Record 29 of Set 6 | lompoc
# Processing Record 30 of Set 6 | zhuhai
# Processing Record 31 of Set 6 | kaeo
# Processing Record 32 of Set 6 | olinda
# Processing Record 33 of Set 6 | diamantina
# Processing Record 34 of Set 6 | san patricio
# Processing Record 35 of Set 6 | buin
# Processing Record 36 of Set 6 | marietta
# Processing Record 37 of Set 6 | longyan
# Processing Record 38 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 6 | uk
# City not found. Skipping...
# Processing Record 40 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 6 | traian
# Processing Record 44 of Set 6 | tezu
# Processing Record 45 of Set 6 | lake havasu city
# Processing Record 46 of Set 6 | correntina
# Processing Record 47 of Set 6 | kesinga
# Processing Record 48 of Set 6 | asfi
# Processing Record 49 of Set 6 | mahibadhoo
# Processing Record 50 of Set 6 | apucarana
# Processing Record 1 of Set 7 | sao domingos do maranhao
# Processing Record 2 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 7 | harper
# Processing Record 4 of Set 7 | cabo san lucas
# Processing Record 5 of Set 7 | nortelandia
# Processing Record 6 of Set 7 | cidreira
# Processing Record 7 of Set 7 | khakhea
# Processing Record 8 of Set 7 | seydi
# Processing Record 9 of Set 7 | whitehorse
# Processing Record 10 of Set 7 | praia da vitoria
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | san andres
# Processing Record 14 of Set 7 | mendi
# Processing Record 15 of Set 7 | nchelenge
# Processing Record 16 of Set 7 | senica
# Processing Record 17 of Set 7 | resistencia
# Processing Record 18 of Set 7 | porterville
# Processing Record 19 of Set 7 | sokoto
# Processing Record 20 of Set 7 | behshahr
# Processing Record 21 of Set 7 | butembo
# Processing Record 22 of Set 7 | gravelbourg
# Processing Record 23 of Set 7 | pamekasan
# Processing Record 24 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 7 | qaanaaq
# Processing Record 26 of Set 7 | barao de melgaco
# Processing Record 27 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 7 | oussouye
# Processing Record 29 of Set 7 | adelaide
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | hamilton
# Processing Record 32 of Set 7 | mae sai
# Processing Record 33 of Set 7 | oga
# Processing Record 34 of Set 7 | constantine
# Processing Record 35 of Set 7 | tsuruoka
# Processing Record 36 of Set 7 | ponta do sol
# Processing Record 37 of Set 7 | norman wells
# Processing Record 38 of Set 7 | saldanha
# Processing Record 39 of Set 7 | luwero
# Processing Record 40 of Set 7 | svetlogorsk
# Processing Record 41 of Set 7 | lokosovo
# Processing Record 42 of Set 7 | matara
# Processing Record 43 of Set 7 | mandalgovi
# Processing Record 44 of Set 7 | nakamura
# Processing Record 45 of Set 7 | port macquarie
# Processing Record 46 of Set 7 | khash
# Processing Record 47 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 48 of Set 7 | sakakah
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | mpulungu
# Processing Record 1 of Set 8 | manado
# Processing Record 2 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 8 | broken hill
# Processing Record 4 of Set 8 | port-gentil
# Processing Record 5 of Set 8 | banjar
# Processing Record 6 of Set 8 | touros
# Processing Record 7 of Set 8 | noumea
# Processing Record 8 of Set 8 | provideniya
# Processing Record 9 of Set 8 | rafraf
# Processing Record 10 of Set 8 | arkhipo-osipovka
# Processing Record 11 of Set 8 | sioux lookout
# Processing Record 12 of Set 8 | mayumba
# Processing Record 13 of Set 8 | avera
# Processing Record 14 of Set 8 | qaqortoq
# Processing Record 15 of Set 8 | mantua
# Processing Record 16 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 8 | alyangula
# Processing Record 18 of Set 8 | westport
# Processing Record 19 of Set 8 | chapada dos guimaraes
# Processing Record 20 of Set 8 | byron bay
# Processing Record 21 of Set 8 | villamontes
# Processing Record 22 of Set 8 | flin flon
# Processing Record 23 of Set 8 | sao felix do xingu
# Processing Record 24 of Set 8 | long eaton
# Processing Record 25 of Set 8 | asau
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 8 | prescott
# Processing Record 29 of Set 8 | beyneu
# Processing Record 30 of Set 8 | hofn
# Processing Record 31 of Set 8 | lorengau
# Processing Record 32 of Set 8 | mitu
# Processing Record 33 of Set 8 | severo-yeniseyskiy
# Processing Record 34 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 35 of Set 8 | ahipara
# Processing Record 36 of Set 8 | manica
# Processing Record 37 of Set 8 | palmer
# Processing Record 38 of Set 8 | klaksvik
# Processing Record 39 of Set 8 | saint-joseph
# Processing Record 40 of Set 8 | tavda
# Processing Record 41 of Set 8 | kargasok
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | masuguru
# Processing Record 44 of Set 8 | carrickfergus
# Processing Record 45 of Set 8 | los llanos de aridane
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | stillwater
# Processing Record 48 of Set 8 | santa maria
# Processing Record 49 of Set 8 | deputatskiy
# Processing Record 50 of Set 8 | niquero
# Processing Record 1 of Set 9 | elko
# Processing Record 2 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 3 of Set 9 | chipata
# Processing Record 4 of Set 9 | kargil
# Processing Record 5 of Set 9 | purranque
# Processing Record 6 of Set 9 | doka
# Processing Record 7 of Set 9 | ballina
# Processing Record 8 of Set 9 | thompson
# Processing Record 9 of Set 9 | lumby
# Processing Record 10 of Set 9 | hammond
# Processing Record 11 of Set 9 | synya
# Processing Record 12 of Set 9 | vao
# Processing Record 13 of Set 9 | inverness
# Processing Record 14 of Set 9 | shirpur
# Processing Record 15 of Set 9 | madingou
# Processing Record 16 of Set 9 | rawlins
# Processing Record 17 of Set 9 | salina
# Processing Record 18 of Set 9 | banikoara
# Processing Record 19 of Set 9 | lieksa
# Processing Record 20 of Set 9 | sola
# Processing Record 21 of Set 9 | krasnyy yar
# Processing Record 22 of Set 9 | filingue
# Processing Record 23 of Set 9 | padang
# Processing Record 24 of Set 9 | biloela
# Processing Record 25 of Set 9 | astaneh-ye ashrafiyeh
# Processing Record 26 of Set 9 | marsa matruh
# Processing Record 27 of Set 9 | ponta delgada
# Processing Record 28 of Set 9 | plettenberg bay
# Processing Record 29 of Set 9 | sorland
# Processing Record 30 of Set 9 | belyy yar
# Processing Record 31 of Set 9 | rawson
# Processing Record 32 of Set 9 | san ramon
# Processing Record 33 of Set 9 | shediac
# Processing Record 34 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 9 | lodja
# Processing Record 36 of Set 9 | vestmannaeyjar
# Processing Record 37 of Set 9 | eureka
# Processing Record 38 of Set 9 | dabat
# Processing Record 39 of Set 9 | peabiru
# Processing Record 40 of Set 9 | mount gambier
# Processing Record 41 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 9 | ketchikan
# Processing Record 43 of Set 9 | baykit
# Processing Record 44 of Set 9 | srandakan
# Processing Record 45 of Set 9 | pisco
# Processing Record 46 of Set 9 | neiafu
# Processing Record 47 of Set 9 | tiksi
# Processing Record 48 of Set 9 | brovst
# Processing Record 49 of Set 9 | kachug
# Processing Record 50 of Set 9 | krasnyy luch
# Processing Record 1 of Set 10 | pokaran
# Processing Record 2 of Set 10 | pokhara
# Processing Record 3 of Set 10 | puerto del rosario
# Processing Record 4 of Set 10 | samarai
# Processing Record 5 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 10 | we
# City not found. Skipping...
# Processing Record 7 of Set 10 | faya
# Processing Record 8 of Set 10 | betanzos
# Processing Record 9 of Set 10 | palana
# Processing Record 10 of Set 10 | santa rosa
# Processing Record 11 of Set 10 | oranjemund
# Processing Record 12 of Set 10 | selma
# Processing Record 13 of Set 10 | oksfjord
# Processing Record 14 of Set 10 | molln
# Processing Record 15 of Set 10 | boyolangu
# Processing Record 16 of Set 10 | jardim
# Processing Record 17 of Set 10 | henties bay
# Processing Record 18 of Set 10 | price
# Processing Record 19 of Set 10 | kruisfontein
# Processing Record 20 of Set 10 | hasilpur
# Processing Record 21 of Set 10 | cockburn town
# Processing Record 22 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 10 | kulpahar
# Processing Record 24 of Set 10 | wlodawa
# Processing Record 25 of Set 10 | auki
# Processing Record 26 of Set 10 | kirakira
# Processing Record 27 of Set 10 | tocopilla
# Processing Record 28 of Set 10 | almaty
# Processing Record 29 of Set 10 | prince rupert
# Processing Record 30 of Set 10 | nuuk
# Processing Record 31 of Set 10 | shibarghan
# City not found. Skipping...
# Processing Record 32 of Set 10 | valkeala
# Processing Record 33 of Set 10 | leshukonskoye
# Processing Record 34 of Set 10 | mosquera
# Processing Record 35 of Set 10 | port augusta
# Processing Record 36 of Set 10 | waddan
# Processing Record 37 of Set 10 | longyearbyen
# Processing Record 38 of Set 10 | peleduy
# Processing Record 39 of Set 10 | atkinson
# Processing Record 40 of Set 10 | gamboma
# Processing Record 41 of Set 10 | pacifica
# Processing Record 42 of Set 10 | caravelas
# Processing Record 43 of Set 10 | ust-kuyga
# Processing Record 44 of Set 10 | shieli
# Processing Record 45 of Set 10 | guasdualito
# Processing Record 46 of Set 10 | saint-augustin
# Processing Record 47 of Set 10 | salalah
# Processing Record 48 of Set 10 | udachnyy
# Processing Record 49 of Set 10 | namatanai
# Processing Record 50 of Set 10 | kroonstad
# Processing Record 1 of Set 11 | bhawanipatna
# Processing Record 2 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 3 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 4 of Set 11 | san blas
# Processing Record 5 of Set 11 | neka
# Processing Record 6 of Set 11 | yatou
# Processing Record 7 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 11 | hakodate
# Processing Record 9 of Set 11 | key west
# Processing Record 10 of Set 11 | ponferrada
# Processing Record 11 of Set 11 | acari
# Processing Record 12 of Set 11 | rio blanco
# Processing Record 13 of Set 11 | elizabeth city
# Processing Record 14 of Set 11 | tukrah
# Processing Record 15 of Set 11 | fayaoue
# Processing Record 16 of Set 11 | juneau
# Processing Record 17 of Set 11 | goroka
# Processing Record 18 of Set 11 | half moon bay
# Processing Record 19 of Set 11 | manaure
# Processing Record 20 of Set 11 | itacare
# Processing Record 21 of Set 11 | shorewood
# Processing Record 22 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 11 | marzuq
# Processing Record 24 of Set 11 | makakilo city
# Processing Record 25 of Set 11 | cabot
# Processing Record 26 of Set 11 | enshi
# Processing Record 27 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 11 | ruidoso
# Processing Record 29 of Set 11 | klyuchi
# Processing Record 30 of Set 11 | golaghat
# Processing Record 31 of Set 11 | teguldet
# Processing Record 32 of Set 11 | camabatela
# Processing Record 33 of Set 11 | tuatapere
# Processing Record 34 of Set 11 | crotone
# Processing Record 35 of Set 11 | chapleau
# Processing Record 36 of Set 11 | reconquista
# Processing Record 37 of Set 11 | necochea
# Processing Record 38 of Set 11 | coahuayana
# Processing Record 39 of Set 11 | zhicheng
# Processing Record 40 of Set 11 | kribi
# Processing Record 41 of Set 11 | puerto lleras
# Processing Record 42 of Set 11 | carbonia
# Processing Record 43 of Set 11 | talnakh
# Processing Record 44 of Set 11 | umm lajj
# Processing Record 45 of Set 11 | berdigestyakh
# Processing Record 46 of Set 11 | kajaani
# Processing Record 47 of Set 11 | townsville
# Processing Record 48 of Set 11 | mwinilunga
# Processing Record 49 of Set 11 | rio gallegos
# Processing Record 50 of Set 11 | kununurra
# Processing Record 1 of Set 12 | cadillac
# Processing Record 2 of Set 12 | honningsvag
# Processing Record 3 of Set 12 | margate
# Processing Record 4 of Set 12 | miri
# Processing Record 5 of Set 12 | kunszentmarton
# Processing Record 6 of Set 12 | skage
# City not found. Skipping...
# Processing Record 7 of Set 12 | baruun-urt
# Processing Record 8 of Set 12 | laguna
# Processing Record 9 of Set 12 | kosh-agach
# Processing Record 10 of Set 12 | vallenar
# Processing Record 11 of Set 12 | mezen
# Processing Record 12 of Set 12 | igarka
# Processing Record 13 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 12 | langsa
# Processing Record 15 of Set 12 | goundi
# Processing Record 16 of Set 12 | yuli
# Processing Record 17 of Set 12 | beloha
# Processing Record 18 of Set 12 | teya
# Processing Record 19 of Set 12 | inhambane
# Processing Record 20 of Set 12 | awbari
# Processing Record 21 of Set 12 | beringovskiy
# Processing Record 22 of Set 12 | otane
# Processing Record 23 of Set 12 | pedasi
# Processing Record 24 of Set 12 | dongsheng
# Processing Record 25 of Set 12 | camopi
# Processing Record 26 of Set 12 | yaval
# Processing Record 27 of Set 12 | san cristobal
# Processing Record 28 of Set 12 | yambio
# Processing Record 29 of Set 12 | uhlove
# Processing Record 30 of Set 12 | tibati
# Processing Record 31 of Set 12 | dunedin
# Processing Record 32 of Set 12 | fomboni
# Processing Record 33 of Set 12 | mount isa
# Processing Record 34 of Set 12 | varangaon
# Processing Record 35 of Set 12 | ixtapa
# Processing Record 36 of Set 12 | busia
# Processing Record 37 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 12 | banihal
# Processing Record 39 of Set 12 | atambua
# Processing Record 40 of Set 12 | muroran
# Processing Record 41 of Set 12 | sabha
# Processing Record 42 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 43 of Set 12 | bowen
# Processing Record 44 of Set 12 | albox
# Processing Record 45 of Set 12 | qostanay
# Processing Record 46 of Set 12 | carballo
# Processing Record 47 of Set 12 | cairo
# Processing Record 48 of Set 12 | kiunga
# Processing Record 49 of Set 12 | mahalapye
# Processing Record 50 of Set 12 | batemans bay
# Processing Record 1 of Set 13 | gorontalo
# Processing Record 2 of Set 13 | san quintin
# Processing Record 3 of Set 13 | bambanglipuro
# Processing Record 4 of Set 13 | banganapalle
# Processing Record 5 of Set 13 | beaverlodge
# Processing Record 6 of Set 13 | denpasar
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | la asuncion
# Processing Record 9 of Set 13 | oktyabrskiy
# Processing Record 10 of Set 13 | karratha
# Processing Record 11 of Set 13 | krasnogorsk
# Processing Record 12 of Set 13 | okhotsk
# Processing Record 13 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 13 | vanimo
# Processing Record 15 of Set 13 | tiznit
# Processing Record 16 of Set 13 | pangoa
# Processing Record 17 of Set 13 | moyale
# Processing Record 18 of Set 13 | thessalon
# Processing Record 19 of Set 13 | marrakesh
# Processing Record 20 of Set 13 | bogande
# Processing Record 21 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 22 of Set 13 | turgutlu
# Processing Record 23 of Set 13 | roald
# Processing Record 24 of Set 13 | cartagena
# Processing Record 25 of Set 13 | haines junction
# Processing Record 26 of Set 13 | nemuro
# Processing Record 27 of Set 13 | salekhard
# Processing Record 28 of Set 13 | sao joao da barra
# Processing Record 29 of Set 13 | labuhan
# Processing Record 30 of Set 13 | aleksandrovka
# Processing Record 31 of Set 13 | marinette
# Processing Record 32 of Set 13 | vittoria
# Processing Record 33 of Set 13 | fort-shevchenko
# Processing Record 34 of Set 13 | lamu
# Processing Record 35 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 13 | gweta
# Processing Record 37 of Set 13 | daru
# Processing Record 38 of Set 13 | shadrinsk
# Processing Record 39 of Set 13 | sandwick
# Processing Record 40 of Set 13 | grindavik
# Processing Record 41 of Set 13 | pasni
# Processing Record 42 of Set 13 | nome
# Processing Record 43 of Set 13 | ishigaki
# Processing Record 44 of Set 13 | srednekolymsk
# Processing Record 45 of Set 13 | yining
# Processing Record 46 of Set 13 | basqal
# Processing Record 47 of Set 13 | velykoploske
# Processing Record 48 of Set 13 | mecca
# Processing Record 49 of Set 13 | korla
# Processing Record 50 of Set 13 | villa carlos paz
# Processing Record 1 of Set 14 | turtas
# Processing Record 2 of Set 14 | black river
# Processing Record 3 of Set 14 | san jose
# Processing Record 4 of Set 14 | lakselv
# Processing Record 5 of Set 14 | bougouni
# Processing Record 6 of Set 14 | salinopolis
# Processing Record 7 of Set 14 | gazanjyk
# Processing Record 8 of Set 14 | erzin
# Processing Record 9 of Set 14 | piedras negras
# Processing Record 10 of Set 14 | lubango
# Processing Record 11 of Set 14 | ahuimanu
# Processing Record 12 of Set 14 | bergen
# Processing Record 13 of Set 14 | dong hoi
# Processing Record 14 of Set 14 | zaraza
# Processing Record 15 of Set 14 | pacific grove
# Processing Record 16 of Set 14 | loyga
# Processing Record 17 of Set 14 | skibbereen
# Processing Record 18 of Set 14 | north platte
# Processing Record 19 of Set 14 | batalha
# Processing Record 20 of Set 14 | saint-ambroise
# Processing Record 21 of Set 14 | faanui
# Processing Record 22 of Set 14 | cururupu
# Processing Record 23 of Set 14 | brae
# Processing Record 24 of Set 14 | waterloo
# Processing Record 25 of Set 14 | kawambwa
# Processing Record 26 of Set 14 | blackfoot
# Processing Record 27 of Set 14 | alice town
# Processing Record 28 of Set 14 | emerald
# Processing Record 29 of Set 14 | jimeta
# Processing Record 30 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 31 of Set 14 | la primavera
# Processing Record 32 of Set 14 | malindi
# Processing Record 33 of Set 14 | keti bandar
# Processing Record 34 of Set 14 | buenos aires
# Processing Record 35 of Set 14 | yulara
# Processing Record 36 of Set 14 | suining
# Processing Record 37 of Set 14 | hastings
# Processing Record 38 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 39 of Set 14 | cantaura
# Processing Record 40 of Set 14 | maningrida
# Processing Record 41 of Set 14 | kovernino
# Processing Record 42 of Set 14 | lampa
# Processing Record 43 of Set 14 | belgrade
# Processing Record 44 of Set 14 | pitimbu
# Processing Record 45 of Set 14 | traverse city
# Processing Record 46 of Set 14 | iqaluit
# Processing Record 47 of Set 14 | dongkan
# Processing Record 48 of Set 14 | lempaala
# Processing Record 49 of Set 14 | dakar
# Processing Record 50 of Set 14 | zhangye
# Processing Record 1 of Set 15 | darhan
# Processing Record 2 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 15 | mopipi
# Processing Record 4 of Set 15 | ucluelet
# Processing Record 5 of Set 15 | tucupita
# Processing Record 6 of Set 15 | siguiri
# Processing Record 7 of Set 15 | hlotse
# Processing Record 8 of Set 15 | saint-georges
# Processing Record 9 of Set 15 | maniitsoq
# Processing Record 10 of Set 15 | tecoanapa
# Processing Record 11 of Set 15 | lermontovka
# Processing Record 12 of Set 15 | namwala
# Processing Record 13 of Set 15 | la paz
# Processing Record 14 of Set 15 | hearst
# Processing Record 15 of Set 15 | acapulco
# Processing Record 16 of Set 15 | kieta
# Processing Record 17 of Set 15 | waipawa
# Processing Record 18 of Set 15 | ulladulla
# Processing Record 19 of Set 15 | chihuahua
# Processing Record 20 of Set 15 | khandyga
# Processing Record 21 of Set 15 | quatre cocos
# Processing Record 22 of Set 15 | mnogovershinnyy
# Processing Record 23 of Set 15 | xam nua
# Processing Record 24 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 15 | birecik
# Processing Record 27 of Set 15 | venado tuerto
# Processing Record 28 of Set 15 | luderitz
# Processing Record 29 of Set 15 | elmadag
# Processing Record 30 of Set 15 | champerico
# Processing Record 31 of Set 15 | tashtagol
# Processing Record 32 of Set 15 | whitley bay
# Processing Record 33 of Set 15 | bilibino
# Processing Record 34 of Set 15 | huarmey
# Processing Record 35 of Set 15 | antalaha
# Processing Record 36 of Set 15 | hualmay
# Processing Record 37 of Set 15 | puerto madryn
# Processing Record 38 of Set 15 | dondo
# Processing Record 39 of Set 15 | alanya
# Processing Record 40 of Set 15 | eenhana
# Processing Record 41 of Set 15 | scarborough
# Processing Record 42 of Set 15 | pemba
# Processing Record 43 of Set 15 | spring valley
# Processing Record 44 of Set 15 | glace bay
# Processing Record 45 of Set 15 | makarov
# Processing Record 46 of Set 15 | veraval
# Processing Record 47 of Set 15 | otradnoye
# Processing Record 48 of Set 15 | itapuranga
# Processing Record 49 of Set 15 | nuh
# Processing Record 50 of Set 15 | sampit
# Processing Record 1 of Set 16 | cambuci
# Processing Record 2 of Set 16 | supaul
# Processing Record 3 of Set 16 | bandarbeyla
# Processing Record 4 of Set 16 | la ronge
# Processing Record 5 of Set 16 | feldru
# Processing Record 6 of Set 16 | palmas bellas
# Processing Record 7 of Set 16 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 16 | uyutne
# Processing Record 9 of Set 16 | dubbo
# Processing Record 10 of Set 16 | yingkou
# Processing Record 11 of Set 16 | yerbogachen
# Processing Record 12 of Set 16 | khorramshahr
# Processing Record 13 of Set 16 | groa
# Processing Record 14 of Set 16 | poso
# Processing Record 15 of Set 16 | anito
# Processing Record 16 of Set 16 | quezada
# Processing Record 17 of Set 16 | emba
# Processing Record 18 of Set 16 | san luis
# Processing Record 19 of Set 16 | vagur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nouadhibou      MR  20.9310 -17.0347     70.20        93          29
# 1     Bubaque      GW  11.2833 -15.8333     80.10        79         100
# 2   Hithadhoo      MV  -0.6000  73.0833     81.25        74         100
# 3     Le Port      RE -20.9373  55.2919     69.80        80          32
# 4     Sechura      PE  -5.5569 -80.8222     73.78        63          15
#
#    Wind Speed Current Description
# 0       14.12          light rain
# 1       14.58     overcast clouds
# 2        7.27     overcast clouds
# 3        4.99    scattered clouds
# 4       14.56          few clouds

# %%
#create the csv file
output_data_file = "cities.csv"
#export the data into the csv
city_data_df.to_csv(output_data_file, index_label ="City_ID")
